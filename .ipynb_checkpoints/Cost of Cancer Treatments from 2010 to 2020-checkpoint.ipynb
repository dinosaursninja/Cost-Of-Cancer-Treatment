# %% [markdown]
# import pandas

# %%
import pandas as pd 
# !pip install ipympl
# %matplotlib widget

#limit the amount of information shown per row
pandas.set_option('display.max_rows', 60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2235bcd1ad1c> in <module>
#       4
#       5 #limit the amount of information shown per row
# ----> 6 pandas.set_option('display.max_rows', 60)
#
# NameError: name 'pandas' is not defined

# %% [markdown]
# Accepts my link as something useful

# %%
 from urllib.request import urlopen

# %% [markdown]
# Store the link with the csv in a var

# %%
data_url = "https://gist.githubusercontent.com/dinosaursninja/cae83a39276ecf50d5c137e3a849fb09/raw/f091c3ac8b71914b79acc8064f935b61ab8eb0cf/Cost%2520of%2520Cancer%2520Treatments%25202010%2520to%25202020"

# %% [markdown]
# Store url in an object

# %%
data = urlopen(data_url)

# %% [markdown]
# Upload that data as a dataframe and store in variable called df

# %%
df = pd.read_csv(data)

# %% [markdown]
# Show the data type for each column in the data set

# %%
df.dtypes
# Out:
# Cancer Site                                                   object
# Year                                                           int64
# Sex                                                           object
# Age                                                           object
# Incidence and Survival Assumptions                            object
# Annual Cost Increase (applied to initial and last phases)     object
# Total Costs                                                  float64
# Initial Year After Diagnosis Cost                            float64
# Continuing Phase Cost                                        float64
# Last Year of Life Cost                                       float64
# dtype: object

# %% [markdown]
# Show the header of the dataset

# %%
df.head()
# Out:
#   Cancer Site  Year         Sex       Age  \
# 0    AllSites  2010  Both sexes  All ages
# 1    AllSites  2010  Both sexes  All ages
# 2    AllSites  2010  Both sexes  All ages
# 3    AllSites  2010  Both sexes  All ages
# 4    AllSites  2010  Both sexes  All ages
#
#                  Incidence and Survival Assumptions  \
# 0               Incidence/Survival at constant rate
# 1  Incidence follows recent trend/Survival constant
# 2  Survival follows recent trend/Incidence constant
# 3           Incidence/Survival follow recent trends
# 4           Incidence/Survival follow recent trends
#
#   Annual Cost Increase (applied to initial and last phases)  Total Costs  \
# 0                                                 0%            124565.6
# 1                                                 0%            122420.8
# 2                                                 0%            125397.7
# 3                                                 0%            123236.3
# 4                                                 2%            123236.3
#
#    Initial Year After Diagnosis Cost  Continuing Phase Cost  \
# 0                            40463.5                46642.8
# 1                            38552.7                46671.9
# 2                            40463.5                47136.3
# 3                            38552.7                47155.7
# 4                            38552.7                47155.7
#
#    Last Year of Life Cost
# 0                 37459.2
# 1                 37196.3
# 2                 37797.9
# 3                 37527.8
# 4                 37527.8

# %% [markdown]
# Summarize

# %%
df.describe()
# Out:
#               Year    Total Costs  Initial Year After Diagnosis Cost  \
# count  1254.000000    1254.000000                        1254.000000
# mean   2015.000000   15221.008852                        4677.505742
# std       3.163539   31489.503603                        9703.258460
# min    2010.000000    1204.600000                         293.000000
# 25%    2012.000000    2866.625000                         939.175000
# 50%    2015.000000    5107.350000                        1377.150000
# 75%    2018.000000   14178.925000                        4883.050000
# max    2020.000000  206587.100000                       68858.000000
#
#        Continuing Phase Cost  Last Year of Life Cost
# count            1254.000000             1254.000000
# mean             5764.655024             4778.848804
# std             12094.699099             9930.281985
# min                98.900000              330.600000
# 25%               846.875000              908.925000
# 50%              1940.350000             1755.200000
# 75%              5187.200000             4465.275000
# max             66099.700000            74159.700000

# %% [markdown]
# ### Explain your dataset and what you would like to do with it.
# Long term, I would like to group the cancer by types and see how the cost of treatment compares amongst the groups.
#
# Short term for this assignment I would like to compare the standard deviation for the three columns (initial cost, contuinuing cost and last year of life) to see how the phases compare from one phase to another in terms of cost.

# %% [markdown]
# ### Add a new Column :
# The column added is the standard deviation (std)
# for intial cost, continuing phase cost and final year of life cost.

# %% [markdown]
# STD tells us the variability, or spread, of a distribution.
# How spread out the data is. It is a measure of how far each observed value is from the mean.

# %%
#print("The standard deviation for column 'Continuing Phase Cost' is: ")
print("The standard deviation for the column 'Continuing Phase Cost' is: ", df['Continuing Phase Cost'].std())
# Out:
# The standard deviation for the column 'Continuing Phase Cost' is:  12094.699098688146

# %%
print(df.columns)
# Out:
# Index(['Cancer Site', 'Year', 'Sex', 'Age',
#        'Incidence and Survival Assumptions',
#        'Annual Cost Increase (applied to initial and last phases)',
#        'Total Costs', 'Initial Year After Diagnosis Cost',
#        'Continuing Phase Cost', 'Last Year of Life Cost'],
#       dtype='object')

# %% [markdown]
# iloc: Isolates the target columns by indexing by number instead of letters. The axis = 1, specifies that it is the columns not rows that you are extracting/isolating.

# %%
df.iloc[:,[-3,-2,-1]].std(axis=1)
# Out:
# 0       4682.379665
# 1       5124.259702
# 2       4810.360308
# 3       5287.697789
# 4       5287.697789
#            ...
# 1249    4892.094920
# 1250    6864.061310
# 1251    6493.607914
# 1252    5955.006260
# 1253    5047.996289
# Length: 1254, dtype: float64

# %% [markdown]
# Store the values you have isolated into the specified column. In this case the Column is being defined simultanously.

# %%
df['Standard Deviation for all Initial, Continuing, and Last year'] = df.iloc[:,[-3,-2,-1]].std(axis=1)

# %%
df.describe()
# Out:
#               Year    Total Costs  Initial Year After Diagnosis Cost  \
# count  1254.000000    1254.000000                        1254.000000
# mean   2015.000000   15221.008852                        4677.505742
# std       3.163539   31489.503603                        9703.258460
# min    2010.000000    1204.600000                         293.000000
# 25%    2012.000000    2866.625000                         939.175000
# 50%    2015.000000    5107.350000                        1377.150000
# 75%    2018.000000   14178.925000                        4883.050000
# max    2020.000000  206587.100000                       68858.000000
#
#        Continuing Phase Cost  Last Year of Life Cost  \
# count            1254.000000             1254.000000
# mean             5764.655024             4778.848804
# std             12094.699099             9930.281985
# min                98.900000              330.600000
# 25%               846.875000              908.925000
# 50%              1940.350000             1755.200000
# 75%              5187.200000             4465.275000
# max             66099.700000            74159.700000
#
#        Standard Deviation for all Initial, Continuing, and Last year
# count                                        1254.000000
# mean                                         1369.796157
# std                                          1655.607430
# min                                           132.721111
# 25%                                           355.310762
# 50%                                           731.501188
# 75%                                          1565.791520
# max                                         10904.125117

# %%
df.head()
# Out:
#   Cancer Site  Year         Sex       Age  \
# 0    AllSites  2010  Both sexes  All ages
# 1    AllSites  2010  Both sexes  All ages
# 2    AllSites  2010  Both sexes  All ages
# 3    AllSites  2010  Both sexes  All ages
# 4    AllSites  2010  Both sexes  All ages
#
#                  Incidence and Survival Assumptions  \
# 0               Incidence/Survival at constant rate
# 1  Incidence follows recent trend/Survival constant
# 2  Survival follows recent trend/Incidence constant
# 3           Incidence/Survival follow recent trends
# 4           Incidence/Survival follow recent trends
#
#   Annual Cost Increase (applied to initial and last phases)  Total Costs  \
# 0                                                 0%            124565.6
# 1                                                 0%            122420.8
# 2                                                 0%            125397.7
# 3                                                 0%            123236.3
# 4                                                 2%            123236.3
#
#    Initial Year After Diagnosis Cost  Continuing Phase Cost  \
# 0                            40463.5                46642.8
# 1                            38552.7                46671.9
# 2                            40463.5                47136.3
# 3                            38552.7                47155.7
# 4                            38552.7                47155.7
#
#    Last Year of Life Cost  \
# 0                 37459.2
# 1                 37196.3
# 2                 37797.9
# 3                 37527.8
# 4                 37527.8
#
#    Standard Deviation for all Initial, Continuing, and Last year
# 0                                        4682.379665
# 1                                        5124.259702
# 2                                        4810.360308
# 3                                        5287.697789
# 4                                        5287.697789

# %% [markdown]
# #### Run a filtering operation by using Dataframe row indexing using a comparison statement that yields a boolean array/matrix.

# %% [markdown]
# Returns true for treatments that cost more during initial phase than the last year of life && creates a new column for that data.

# %%
df['Initial Cost Exceeds Last Year of Life'] = df['Initial Year After Diagnosis Cost'] > df['Last Year of Life Cost']

# %%
df.head()
# Out:
#   Cancer Site  Year         Sex       Age  \
# 0    AllSites  2010  Both sexes  All ages
# 1    AllSites  2010  Both sexes  All ages
# 2    AllSites  2010  Both sexes  All ages
# 3    AllSites  2010  Both sexes  All ages
# 4    AllSites  2010  Both sexes  All ages
#
#                  Incidence and Survival Assumptions  \
# 0               Incidence/Survival at constant rate
# 1  Incidence follows recent trend/Survival constant
# 2  Survival follows recent trend/Incidence constant
# 3           Incidence/Survival follow recent trends
# 4           Incidence/Survival follow recent trends
#
#   Annual Cost Increase (applied to initial and last phases)  Total Costs  \
# 0                                                 0%            124565.6
# 1                                                 0%            122420.8
# 2                                                 0%            125397.7
# 3                                                 0%            123236.3
# 4                                                 2%            123236.3
#
#    Initial Year After Diagnosis Cost  Continuing Phase Cost  \
# 0                            40463.5                46642.8
# 1                            38552.7                46671.9
# 2                            40463.5                47136.3
# 3                            38552.7                47155.7
# 4                            38552.7                47155.7
#
#    Last Year of Life Cost  \
# 0                 37459.2
# 1                 37196.3
# 2                 37797.9
# 3                 37527.8
# 4                 37527.8
#
#    Standard Deviation for all Initial, Continuing, and Last year  \
# 0                                        4682.379665
# 1                                        5124.259702
# 2                                        4810.360308
# 3                                        5287.697789
# 4                                        5287.697789
#
#    Initial Cost Exceeds Last Year of Life
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True

# %% [markdown]
# #### Change the index of your dataset using the set_index method to one of your columns and display the resulting table:

# %% [markdown]
# Change the index of your dataset using the set_index method to one of your columns and display the resulting table.

# %%
df.set_index('Cancer Site', inplace=True)

# %%
df.head()
# Out:
#              Year         Sex       Age  \
# Cancer Site
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
#
#                            Incidence and Survival Assumptions  \
# Cancer Site
# AllSites                  Incidence/Survival at constant rate
# AllSites     Incidence follows recent trend/Survival constant
# AllSites     Survival follows recent trend/Incidence constant
# AllSites              Incidence/Survival follow recent trends
# AllSites              Incidence/Survival follow recent trends
#
#             Annual Cost Increase (applied to initial and last phases)  \
# Cancer Site
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    2%
#
#              Total Costs  Initial Year After Diagnosis Cost  \
# Cancer Site
# AllSites        124565.6                            40463.5
# AllSites        122420.8                            38552.7
# AllSites        125397.7                            40463.5
# AllSites        123236.3                            38552.7
# AllSites        123236.3                            38552.7
#
#              Continuing Phase Cost  Last Year of Life Cost  \
# Cancer Site
# AllSites                   46642.8                 37459.2
# AllSites                   46671.9                 37196.3
# AllSites                   47136.3                 37797.9
# AllSites                   47155.7                 37527.8
# AllSites                   47155.7                 37527.8
#
#              Standard Deviation for all Initial, Continuing, and Last year  \
# Cancer Site
# AllSites                                           4682.379665
# AllSites                                           5124.259702
# AllSites                                           4810.360308
# AllSites                                           5287.697789
# AllSites                                           5287.697789
#
#              Initial Cost Exceeds Last Year of Life
# Cancer Site
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True

# %% [markdown]
# #### Select a subset of rows from your dataset, and save it in a separate file as CSV or another format (see Ch 6)

# %%
#Subset of rows ~ come back to this

# %% [markdown]
# ### Possibly the beginning of Stage 3:

# %% [markdown]
# #### Count the missing values in your dataset and indicate how many in rows and columns indicate how many in rows and columns:
#  DataFrame.isnull() detects missing values returns True or False.
#  DataFrame.sum() returns the sum of the values for the requested axis.

# %%
print("Missing values are: \n\n ", df.isnull())
# Out:
# Missing values are:
#
#                 Year    Sex    Age  Incidence and Survival Assumptions  \
# Cancer Site
# AllSites     False  False  False                               False
# AllSites     False  False  False                               False
# AllSites     False  False  False                               False
# AllSites     False  False  False                               False
# AllSites     False  False  False                               False
# ...            ...    ...    ...                                 ...
# Other        False  False  False                               False
# Other        False  False  False                               False
# Other        False  False  False                               False
# Other        False  False  False                               False
# Other        False  False  False                               False
#
#              Annual Cost Increase (applied to initial and last phases)  \
# Cancer Site
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# ...                                                        ...
# Other                                                    False
# Other                                                    False
# Other                                                    False
# Other                                                    False
# Other                                                    False
#
#              Total Costs  Initial Year After Diagnosis Cost  \
# Cancer Site
# AllSites           False                              False
# AllSites           False                              False
# AllSites           False                              False
# AllSites           False                              False
# AllSites           False                              False
# ...                  ...                                ...
# Other              False                              False
# Other              False                              False
# Other              False                              False
# Other              False                              False
# Other              False                              False
#
#              Continuing Phase Cost  Last Year of Life Cost  \
# Cancer Site
# AllSites                     False                   False
# AllSites                     False                   False
# AllSites                     False                   False
# AllSites                     False                   False
# AllSites                     False                   False
# ...                            ...                     ...
# Other                        False                   False
# Other                        False                   False
# Other                        False                   False
# Other                        False                   False
# Other                        False                   False
#
#              Standard Deviation for all Initial, Continuing, and Last year  \
# Cancer Site
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# AllSites                                                 False
# ...                                                        ...
# Other                                                    False
# Other                                                    False
# Other                                                    False
# Other                                                    False
# Other                                                    False
#
#              Initial Cost Exceeds Last Year of Life
# Cancer Site
# AllSites                                      False
# AllSites                                      False
# AllSites                                      False
# AllSites                                      False
# AllSites                                      False
# ...                                             ...
# Other                                         False
# Other                                         False
# Other                                         False
# Other                                         False
# Other                                         False
#
# [1254 rows x 11 columns]

# %%
print("Count of the total of the missing values are for each of the columns: \n \n ", df.isnull().sum())
# Out:
# Count of the total of the missing values are for each of the columns:
#
#   Year                                                             0
# Sex                                                              0
# Age                                                              0
# Incidence and Survival Assumptions                               0
# Annual Cost Increase (applied to initial and last phases)        0
# Total Costs                                                      0
# Initial Year After Diagnosis Cost                                0
# Continuing Phase Cost                                            0
# Last Year of Life Cost                                           0
# Standard Deviation for all Initial, Continuing, and Last year    0
# Initial Cost Exceeds Last Year of Life                           0
# dtype: int64

# %%
for i in range(len(df.index)):

print("Count of the total of the missing values are for each of the rows: \n \n ", i + 1, ":" , df.iloc[i].isnull().sum())
# Out:
#   File "<ipython-input-25-5461e991f1c8>", line 3
#     print("Count of the total of the missing values are for each of the rows: \n \n ", i + 1, ":" , df.iloc[i].isnull().sum())
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# #### Remove rows or columns of missing values from your dataset:
# DataFrame.dropna(self, axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
print("removes NaN values from columns: "), df.dropna(axis ='columns', thresh=2)
print("removes NaN values from rows: "), df.dropna(thresh=2)
# Out:
# removes NaN values from columns:
# removes NaN values from rows:
# (None,
#               Year         Sex       Age  \
#  Cancer Site
#  AllSites     2010  Both sexes  All ages
#  AllSites     2010  Both sexes  All ages
#  AllSites     2010  Both sexes  All ages
#  AllSites     2010  Both sexes  All ages
#  AllSites     2010  Both sexes  All ages
#  ...           ...         ...       ...
#  Other        2020  Both sexes  All ages
#  Other        2020  Both sexes  All ages
#  Other        2020  Both sexes  All ages
#  Other        2020  Both sexes  All ages
#  Other        2020  Both sexes  All ages
#
#                             Incidence and Survival Assumptions  \
#  Cancer Site
#  AllSites                  Incidence/Survival at constant rate
#  AllSites     Incidence follows recent trend/Survival constant
#  AllSites     Survival follows recent trend/Incidence constant
#  AllSites              Incidence/Survival follow recent trends
#  AllSites              Incidence/Survival follow recent trends
#  ...                                                       ...
#  Other        Incidence follows recent trend/Survival constant
#  Other        Survival follows recent trend/Incidence constant
#  Other                 Incidence/Survival follow recent trends
#  Other                 Incidence/Survival follow recent trends
#  Other                 Incidence/Survival follow recent trends
#
#              Annual Cost Increase (applied to initial and last phases)  \
#  Cancer Site
#  AllSites                                                    0%
#  AllSites                                                    0%
#  AllSites                                                    0%
#  AllSites                                                    0%
#  AllSites                                                    2%
#  ...                                                        ...
#  Other                                                       0%
#  Other                                                       0%
#  Other                                                       0%
#  Other                                                       2%
#  Other                                                       5%
#
#               Total Costs  Initial Year After Diagnosis Cost  \
#  Cancer Site
#  AllSites        124565.6                            40463.5
#  AllSites        122420.8                            38552.7
#  AllSites        125397.7                            40463.5
#  AllSites        123236.3                            38552.7
#  AllSites        123236.3                            38552.7
#  ...                  ...                                ...
#  Other            26945.7                             4432.4
#  Other            29975.9                             4466.2
#  Other            30892.3                             4432.4
#  Other            33201.2                             5403.1
#  Other            37522.8                             7219.9
#
#               Continuing Phase Cost  Last Year of Life Cost  \
#  Cancer Site
#  AllSites                   46642.8                 37459.2
#  AllSites                   46671.9                 37196.3
#  AllSites                   47136.3                 37797.9
#  AllSites                   47155.7                 37527.8
#  AllSites                   47155.7                 37527.8
#  ...                            ...                     ...
#  Other                      14156.5                  8356.8
#  Other                      17675.7                  7834.0
#  Other                      17275.7                  9184.3
#  Other                      17275.7                 10522.5
#  Other                      17275.7                 13027.2
#
#               Standard Deviation for all Initial, Continuing, and Last year  \
#  Cancer Site
#  AllSites                                           4682.379665
#  AllSites                                           5124.259702
#  AllSites                                           4810.360308
#  AllSites                                           5287.697789
#  AllSites                                           5287.697789
#  ...                                                        ...
#  Other                                              4892.094920
#  Other                                              6864.061310
#  Other                                              6493.607914
#  Other                                              5955.006260
#  Other                                              5047.996289
#
#               Initial Cost Exceeds Last Year of Life
#  Cancer Site
#  AllSites                                       True
#  AllSites                                       True
#  AllSites                                       True
#  AllSites                                       True
#  AllSites                                       True
#  ...                                             ...
#  Other                                         False
#  Other                                         False
#  Other                                         False
#  Other                                         False
#  Other                                         False
#
#  [1254 rows x 11 columns])

# %% [markdown]
# #### Replace missing values in one column or row with a specified value ~ This does not work for my dataset since it does not contain misssing values and I would like to maintain the integrity of the data.

# %% [markdown]
# ## Make the following graphs, but make sure they have proper axis labels and titles:

# %% [markdown]
# 1. Select three numerical columns and display their distributions by bar plotting. You can either use the hist() method in matplotlib or the output of the value_counts() method in pandas

# %%
df.head()
# Out:
#              Year         Sex       Age  \
# Cancer Site
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
#
#                            Incidence and Survival Assumptions  \
# Cancer Site
# AllSites                  Incidence/Survival at constant rate
# AllSites     Incidence follows recent trend/Survival constant
# AllSites     Survival follows recent trend/Incidence constant
# AllSites              Incidence/Survival follow recent trends
# AllSites              Incidence/Survival follow recent trends
#
#             Annual Cost Increase (applied to initial and last phases)  \
# Cancer Site
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    2%
#
#              Total Costs  Initial Year After Diagnosis Cost  \
# Cancer Site
# AllSites        124565.6                            40463.5
# AllSites        122420.8                            38552.7
# AllSites        125397.7                            40463.5
# AllSites        123236.3                            38552.7
# AllSites        123236.3                            38552.7
#
#              Continuing Phase Cost  Last Year of Life Cost  \
# Cancer Site
# AllSites                   46642.8                 37459.2
# AllSites                   46671.9                 37196.3
# AllSites                   47136.3                 37797.9
# AllSites                   47155.7                 37527.8
# AllSites                   47155.7                 37527.8
#
#              Standard Deviation for all Initial, Continuing, and Last year  \
# Cancer Site
# AllSites                                           4682.379665
# AllSites                                           5124.259702
# AllSites                                           4810.360308
# AllSites                                           5287.697789
# AllSites                                           5287.697789
#
#              Initial Cost Exceeds Last Year of Life
# Cancer Site
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True

# %%
import matplotlib.pyplot as plt
slice = df[['Initial Year After Diagnosis Cost', 'Continuing Phase Cost','Last Year of Life Cost']]

#The number of rows that match a certain price by stage of treatment.
graph = slice.plot.hist()
graph.set_title('Cost by Phase')
graph.set_xlabel('Cost')
graph.set_ylabel('Ocurrance Frequency')
# Out:
# Text(0, 0.5, 'Ocurrance Frequency')

# %% [markdown]
# 2. Arrange the previous set of plots into vertically-aligned subplots of one figure.

# %%
# come back to this

import matplotlib.pyplot as plt

slice1 = df[['Initial Year After Diagnosis Cost']]
slice2 = df[['Continuing Phase Cost']]
slice3 = df[['Last Year of Life Cost']]

# graph = slice.add_subplot()
# graph.set_title('Cost by Phase')

fig, slice1 = plt.subplots(2)

fig.suptitle('Vertically aligned subplots of Treatment Cost')
#fig.set_xlabel('Cost')
#fig.set_ylabel('Search Frequency')
# Out:
# Text(0.5, 0.98, 'Vertically aligned subplots of Treatment Cost')

# %% [markdown]
# 3. Select two numerical columns and plot a line graph showing the relationship between them. (use markers or make a scatter plot)

# %%
slice = df[['Initial Year After Diagnosis Cost', 'Last Year of Life Cost']]
graph = slice.plot.scatter(x = 'Last Year of Life Cost', y= 'Initial Year After Diagnosis Cost')

# %% [markdown]
# 4. Select more than two numerical columns and plot a multi-line graph with different markers/colors comparing them (see matplotlib.pylot.plot for list of markers). Use different row subsets if you don't have enough columns to compare. Show a legend. Add a text annotation.

# %% [markdown]
# The data is grouped by index, 'Cancer Site' (this is both an index and a column),so that the three numerical columns being compared (initial, continuous and final cost) are organized in terms of cancer location.
#
#
# We then take the average cost for each group, using the mean()function.This is so that the avergae price for each group is what is being evaluated.
# We are sorting in acending order according to the total cost.
# A friend suggested it would be a great idea that the data be sorted in descending order based on the total cost of the procedure. I used this idea and organized it in terms of ascending order by total cost.
#
#
# We rotate the x axis by 45, and adjust the size of the graph using sizefig, so that the labels/graphs won't overlap. Similarly, the function plt.xticks(size, labels)  makes all of the labels on the x axis readable (on trial 1 it would condense it so not all of them showed.)

# %%
import numpy as np

####Trial 2
phaseCostGraph = df.groupby('Cancer Site').mean()[['Initial Year After Diagnosis Cost','Continuing Phase Cost','Last Year of Life Cost', 'Total Costs']].sort_values('Total Costs', ascending=True).drop('Total Costs', axis=1)

#adjust how data is displayed
phaseCostGraph.plot.bar(rot=45, figsize=(10, 5))
plt.xticks(np.arange(len(phaseCostGraph.index)), phaseCostGraph.index)
plt.show()


##### Trial 1
#slice = df[['Initial Year After Diagnosis Cost','Continuing Phase Cost','Last Year of Life Cost']]
# graph = df['Initial Year After Diagnosis Cost'].plot(
#     kind='line',
#     marker='*',
#     legend=True,
#     figsize=(10,5),
#     label='Initial Year After Diagnosis Cost')
# df['Continuing Phase Cost'].plot(
#     kind='line',
#     ax=graph,
#     marker='h',
#     legend=True,
#     label='Continuing Phase Cost')
# df['Last Year of Life Cost'].plot(
#     kind='line',
#     ax=graph,
#     marker='o',
#     legend=True,
#     label='Last Year of Life Cost')

#graph.set_title('Cost comparison in different stages by site')
# graph

# %%
Im driving myself insanse running in a loop. 
Does it make sense to do that or Im I jumping the gun
I need to get a good night sleep
# Out:
#   File "<ipython-input-49-65e4f3edf318>", line 1
#     Im driving myself insanse running in a loop.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 5. Select a categorical (text) column and another numerical column, set the dataframe index to the categorical column and display a bar plot of the numerical column where the x-axis labels show the categories.
#
# My index has already been set to a categorical column in earlier stages of this project. As it stands, the index is the column 'Cancer Site'.
# Here the end of life cost for each site is being compared.

# %%
import numpy as np
                   
graph = df.groupby('Cancer Site').mean()['Last Year of Life Cost'].drop('AllSites')
                   
#adjust how data is displayed
graph.plot.bar(rot=45, figsize=(10, 5))
plt.xticks(np.arange(len(graph.index)), graph.index)
plt.show()

# %% [markdown]
# Flip axis (Here I might to evaluate the overall cost by Phase, rather than site.)

# %%
####flip axis stage 4 (R)
import numpy as np
import pandas 

#graph = df.groupby('Cancer Site').mean()['Last Year of Life Cost'].drop('AllSites')
#graph.transpose(copy=True)                   
    
#adjust how data is displayed
#graph.plot.bar(rot=45, figsize=(10, 5))
#plt.xticks(np.arange(len(graph.index)), graph.index)
#plt.show()

# %% [markdown]
# 6. Save one of your figures as a png file.

# %%
                   
graph = df.groupby('Cancer Site').mean()['Last Year of Life Cost'].drop('AllSites')
                   
#adjust how data is displayed
#graph.plot.bar(rot=45, figsize=(10, 5))
#plt.xticks(np.arange(len(graph.index)), graph.index)
#plt.show()

graph.plot.bar().get_figure().savefig('EndoflifeCostbyCancersiteComparison')

# %% [markdown]
# ## Stage 4

# %% [markdown]
# In your notebook, do the following in separate code cells, and each cell, put the variable name alone in the last line of the cell so the output is displayed:
#
#
# Record a video of your screen while you are narrating an explanation of your main results. Start by introducing the features of your dataset, and finish by highlighting your plots and final manipulations in this stage. Keep it below 10 minutes. Upload your video to a cloud drive (OneDrive, Google Drive, Dropbox, etc) and post a link readable by all here.
# Re-post a link to your project notebook here (Colab or Github). Don't forget to share from Colab with us by selecting "anyone with link - view". Attach additional files or explain what is new.

# %% [markdown]
# #### 1. Hierarchical Indexing:

# %% [markdown]
# Identify two columns in your dataset such that one has repeating values and the second one can be considered a sub-category of the first one (for example, "state" and "city"). Use the .set_index() method and provide both of these columns in a list to create a hierachical index in a new dataframe.

# %%
df.head()
# Out:
#              Year         Sex       Age  \
# Cancer Site
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
# AllSites     2010  Both sexes  All ages
#
#                            Incidence and Survival Assumptions  \
# Cancer Site
# AllSites                  Incidence/Survival at constant rate
# AllSites     Incidence follows recent trend/Survival constant
# AllSites     Survival follows recent trend/Incidence constant
# AllSites              Incidence/Survival follow recent trends
# AllSites              Incidence/Survival follow recent trends
#
#             Annual Cost Increase (applied to initial and last phases)  \
# Cancer Site
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    0%
# AllSites                                                    2%
#
#              Total Costs  Initial Year After Diagnosis Cost  \
# Cancer Site
# AllSites        124565.6                            40463.5
# AllSites        122420.8                            38552.7
# AllSites        125397.7                            40463.5
# AllSites        123236.3                            38552.7
# AllSites        123236.3                            38552.7
#
#              Continuing Phase Cost  Last Year of Life Cost  \
# Cancer Site
# AllSites                   46642.8                 37459.2
# AllSites                   46671.9                 37196.3
# AllSites                   47136.3                 37797.9
# AllSites                   47155.7                 37527.8
# AllSites                   47155.7                 37527.8
#
#              Standard Deviation for all Initial, Continuing, and Last year  \
# Cancer Site
# AllSites                                           4682.379665
# AllSites                                           5124.259702
# AllSites                                           4810.360308
# AllSites                                           5287.697789
# AllSites                                           5287.697789
#
#              Initial Cost Exceeds Last Year of Life
# Cancer Site
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True
# AllSites                                       True

# %% [markdown]
# Insert in place = true could not be included because it would no t aow the results.

# %%
df = df.reset_index().set_index(['Year', 'Cancer Site'])
df
# Out:
#                          Sex       Age  \
# Year Cancer Site
# 2010 AllSites     Both sexes  All ages
#      AllSites     Both sexes  All ages
#      AllSites     Both sexes  All ages
#      AllSites     Both sexes  All ages
#      AllSites     Both sexes  All ages
# ...                      ...       ...
# 2020 Other        Both sexes  All ages
#      Other        Both sexes  All ages
#      Other        Both sexes  All ages
#      Other        Both sexes  All ages
#      Other        Both sexes  All ages
#
#                                 Incidence and Survival Assumptions  \
# Year Cancer Site
# 2010 AllSites                  Incidence/Survival at constant rate
#      AllSites     Incidence follows recent trend/Survival constant
#      AllSites     Survival follows recent trend/Incidence constant
#      AllSites              Incidence/Survival follow recent trends
#      AllSites              Incidence/Survival follow recent trends
# ...                                                            ...
# 2020 Other        Incidence follows recent trend/Survival constant
#      Other        Survival follows recent trend/Incidence constant
#      Other                 Incidence/Survival follow recent trends
#      Other                 Incidence/Survival follow recent trends
#      Other                 Incidence/Survival follow recent trends
#
#                  Annual Cost Increase (applied to initial and last phases)  \
# Year Cancer Site
# 2010 AllSites                                                    0%
#      AllSites                                                    0%
#      AllSites                                                    0%
#      AllSites                                                    0%
#      AllSites                                                    2%
# ...                                                             ...
# 2020 Other                                                       0%
#      Other                                                       0%
#      Other                                                       0%
#      Other                                                       2%
#      Other                                                       5%
#
#                   Total Costs  Initial Year After Diagnosis Cost  \
# Year Cancer Site
# 2010 AllSites        124565.6                            40463.5
#      AllSites        122420.8                            38552.7
#      AllSites        125397.7                            40463.5
#      AllSites        123236.3                            38552.7
#      AllSites        123236.3                            38552.7
# ...                       ...                                ...
# 2020 Other            26945.7                             4432.4
#      Other            29975.9                             4466.2
#      Other            30892.3                             4432.4
#      Other            33201.2                             5403.1
#      Other            37522.8                             7219.9
#
#                   Continuing Phase Cost  Last Year of Life Cost  \
# Year Cancer Site
# 2010 AllSites                   46642.8                 37459.2
#      AllSites                   46671.9                 37196.3
#      AllSites                   47136.3                 37797.9
#      AllSites                   47155.7                 37527.8
#      AllSites                   47155.7                 37527.8
# ...                                 ...                     ...
# 2020 Other                      14156.5                  8356.8
#      Other                      17675.7                  7834.0
#      Other                      17275.7                  9184.3
#      Other                      17275.7                 10522.5
#      Other                      17275.7                 13027.2
#
#                   Standard Deviation for all Initial, Continuing, and Last year  \
# Year Cancer Site
# 2010 AllSites                                           4682.379665
#      AllSites                                           5124.259702
#      AllSites                                           4810.360308
#      AllSites                                           5287.697789
#      AllSites                                           5287.697789
# ...                                                             ...
# 2020 Other                                              4892.094920
#      Other                                              6864.061310
#      Other                                              6493.607914
#      Other                                              5955.006260
#      Other                                              5047.996289
#
#                   Initial Cost Exceeds Last Year of Life
# Year Cancer Site
# 2010 AllSites                                       True
#      AllSites                                       True
#      AllSites                                       True
#      AllSites                                       True
#      AllSites                                       True
# ...                                                  ...
# 2020 Other                                         False
#      Other                                         False
#      Other                                         False
#      Other                                         False
#      Other                                         False
#
# [1254 rows x 10 columns]

# %%
#save the dataframe
df.to_csv('modifiedDataframe.csv')

#store that new file in a df so that it can be accessed and manipulated and print that to the console to see
df4 = df.copy()

# %% [markdown]
# In this new dataframe, select only one column of data and use the .unstack() operation to reshape your data.

# %%
df4['Age']
# Out:
# Year  Cancer Site
# 2010  AllSites       All ages
#       AllSites       All ages
#       AllSites       All ages
#       AllSites       All ages
#       AllSites       All ages
#                        ...
# 2020  Other          All ages
#       Other          All ages
#       Other          All ages
#       Other          All ages
#       Other          All ages
# Name: Age, Length: 1254, dtype: object

# %%
df4.groupby(['Year','Cancer Site']).mean()
# Out:
#                     Total Costs  Initial Year After Diagnosis Cost  \
# Year Cancer Site
# 2010 AllSites     123682.166667                       39189.633333
#      Bladder        3921.550000                         941.766667
#      Brain          4469.633333                        1246.800000
#      Breast        16121.783333                        5769.000000
#      Cervix         1444.833333                         421.500000
# ...                         ...                                ...
# 2020 Ovary          5520.000000                        1149.166667
#      Pancreas       3435.150000                        1966.816667
#      Prostate      16532.800000                        6403.883333
#      Stomach        2251.316667                         958.566667
#      Uterus         3166.100000                        1353.900000
#
#                   Continuing Phase Cost  Last Year of Life Cost  \
# Year Cancer Site
# 2010 AllSites              46986.350000            37506.133333
#      Bladder                1882.966667             1096.900000
#      Brain                  1067.050000             2155.783333
#      Breast                 6678.783333             3674.000000
#      Cervix                  359.916667              663.383333
# ...                                 ...                     ...
# 2020 Ovary                  1802.150000             2568.666667
#      Pancreas                201.633333             1266.700000
#      Prostate               8600.233333             1528.650000
#      Stomach                 286.983333             1005.750000
#      Uterus                  874.250000              937.916667
#
#                   Standard Deviation for all Initial, Continuing, and Last year  \
# Year Cancer Site
# 2010 AllSites                                           5080.015507
#      Bladder                                             504.690674
#      Brain                                               583.688168
#      Breast                                             1543.033643
#      Cervix                                              162.087886
# ...                                                             ...
# 2020 Ovary                                               725.481849
#      Pancreas                                            891.376381
#      Prostate                                           3677.281239
#      Stomach                                             403.461905
#      Uterus                                              267.305413
#
#                   Initial Cost Exceeds Last Year of Life
# Year Cancer Site
# 2010 AllSites                                   1.000000
#      Bladder                                    0.000000
#      Brain                                      0.000000
#      Breast                                     1.000000
#      Cervix                                     0.000000
# ...                                                  ...
# 2020 Ovary                                      0.000000
#      Pancreas                                   1.000000
#      Prostate                                   1.000000
#      Stomach                                    0.166667
#      Uterus                                     1.000000
#
# [209 rows x 6 columns]

# %%
df4.groupby(['Year','Cancer Site']).mean()['Total Costs'].unstack()
# Out:
# Cancer Site       AllSites      Bladder        Brain        Breast  \
# Year
# 2010         123682.166667  3921.550000  4469.633333  16121.783333
# 2011         127559.300000  3997.866667  4618.250000  16589.483333
# 2012         131526.466667  4078.116667  4769.900000  17060.683333
# 2013         135538.600000  4161.500000  4925.183333  17531.716667
# Calculate summary statistics based on your hierarchical indexing using the an aggregate method such as sum, mean, etc. For instance: df.sum(level='state')

# %%
df4.mean(level='Cancer Site')

#gives you avrg cost for each site cancer accross 2  decades.
# Out:
#                Total Costs  Initial Year After Diagnosis Cost  \
# Cancer Site
# AllSites     144599.589394                       44436.300000
# Bladder        4368.340909                        1074.792424
# Brain          5280.210606                        1411.780303
# Breast        18525.166667                        6441.813636
# Cervix         1441.734848                         411.710606
# Colorectal    15131.101515                        6114.137879
# Esophagus      1713.387879                         673.792424
# Head_Neck      3947.369697                        1131.671212
# Kidney         5045.562121                        1555.842424
# Leukemia       6373.959091                         882.762121
# Lung          13113.968182                        5519.134848
# Lymphoma      14252.680303                        3604.862121
# Melanoma       3058.759091                         681.112121
# Ovary          5200.456061                        1165.466667
# Pancreas       2826.672727                        1681.503030
# Prostate      13977.395455                        5357.566667
# Stomach        1982.736364                         859.900000
# Uterus         2840.590909                        1180.363636
# Other         25519.486364                        4688.096970
#
#              Continuing Phase Cost  Last Year of Life Cost  \
# Cancer Site
# AllSites              54764.230303            45399.059091
# Bladder                2041.578788             1251.986364
# Brain                  1227.665152             2640.762121
# Breast                 7673.145455             4410.221212
# Cervix                  348.140909              681.877273
# Colorectal             4237.968182             4778.995455
# Esophagus               201.901515              837.692424
# Head_Neck              1078.453030             1737.236364
# Kidney                 2020.209091             1469.525758
# Leukemia               2413.171212             3078.027273
# Lung                   1999.442424             5595.389394
# Lymphoma               5598.459091             5049.359091
# Melanoma               1950.481818              427.172727
# Ovary                  1733.545455             2301.440909
# Pancreas                152.203030              992.963636
# Prostate               7320.310606             1299.513636
# Stomach                 256.603030              866.237879
# Uterus                  823.245455              836.966667
# Other                 13687.690909             7143.700000
#
#              Standard Deviation for all Initial, Continuing, and Last year  \
# Cancer Site
# AllSites                                           6138.113737
# Bladder                                             515.372448
# Brain                                               770.173292
# Breast                                             1682.374955
# Cervix                                              180.031751
# Colorectal                                          975.344701
# Esophagus                                           332.052185
# Head_Neck                                           369.018609
# Kidney                                              312.691077
# Leukemia                                           1134.901725
# Lung                                               2056.875173
# Lymphoma                                           1075.051887
# Melanoma                                            817.266933
# Ovary                                               575.182227
# Pancreas                                            767.517052
# Prostate                                           3088.718702
# Stomach                                             351.111074
# Uterus                                              205.401390
# Other                                              4678.928069
#
#              Initial Cost Exceeds Last Year of Life
# Cancer Site
# AllSites                                   0.409091
# Bladder                                    0.000000
# Brain                                      0.000000
# Breast                                     1.000000
# Cervix                                     0.000000
# Colorectal                                 1.000000
# Esophagus                                  0.000000
# Head_Neck                                  0.000000
# Kidney                                     0.742424
# Leukemia                                   0.000000
# Lung                                       0.303030
# Lymphoma                                   0.000000
# Melanoma                                   1.000000
# Ovary                                      0.000000
# Pancreas                                   1.000000
# Prostate                                   1.000000
# Stomach                                    0.424242
# Uterus                                     1.000000
# Other                                      0.000000

# %% [markdown]
# Go back to your original dataset, and this time try to reach the same outcome that you received by unstack() above by using .pivot(). Set the row, column, and value parameters accordingly (hint: check out end of Chapter 8). Briefly explain how this compared to the method above in a text cell.

#
# Cancer Site      Stomach       Uterus
# Year
# 2010         1750.466667  2570.316667
# 2011         1791.433333  2614.250000
# 2012         1833.683333  2661.616667
# 2013         1876.766667  2711.833333
# 2014         1922.466667  2765.850000
# 2015         1969.500000  2820.966667
# 2016         2020.450000  2882.183333
# 2017         2074.283333  2947.416667
# 2018         2130.216667  3016.133333
# 2019         2189.516667  3089.833333
# 2020         2251.316667  3166.100000

# %% [markdown]
# Go back to your original dataset again, and use the .groupby() method and select one of the same index columns or a different one. Apply a summary statistic function (see textbook Table 10-1 for a list) to the resulting object. Finish by applying .unstack() to the grouped object and explain what you receive in a text cell.

# %%
df.groupby('Cancer Site').mean().unstack()
# Out:
#                                         Cancer Site
# Total Costs                             AllSites       144599.589394
#                                         Bladder          4368.340909
#                                         Brain            5280.210606
#                                         Breast          18525.166667
#                                         Cervix           1441.734848
#                                                            ...
# Initial Cost Exceeds Last Year of Life  Ovary               0.000000
#                                         Pancreas            1.000000
#                                         Prostate            1.000000
#                                         Stomach             0.424242
#                                         Uterus              1.000000
# Length: 114, dtype: float64

# %%
pandas.set_option('display.max_rows', None)

# %% [markdown]
# We have __ modified our orinial idea tp use year and cancer site,
# so inteased now we use the cancer site.
# The cancer site is the second and the rst of the columns are
# part of the first elulevbe.
#
# We are getting the average for the different cancer sites
# where the all of the different numeric columns overlap.

# %% [markdown]
# ### 2. Merge and Concat
#
# For the following steps, split your dataset vertically into two subsets by selecting different sets of columns for each. Delete some rows in one subset based on any condition.
#
#     - merge() for combining data on common columns or indices
#     - .join() for combining data on a key column or an index
#     - concat() for combining DataFrames across rows or columns

# %%
sub1= df.groupby(['Year','Cancer Site']).mean()['Total Costs']
sub2 = df.groupby(['Year','Cancer Site']).mean()['Initial Year After Diagnosis Cost'] 
#I wasnted to use cancer site but couldnt for sub2 because it would show teice in the data
#.I just use initial cost instead this one but it does not make any sense.

# %%
#we want to eliminate all the <500000
sub1= sub1[sub1>5000]

# %%
print(sub1)
# Out:
# Year  Cancer Site
# 2010  AllSites       123682.166667
#       Breast          16121.783333
#       Colorectal      13611.550000
#       Leukemia         5372.783333
#       Lung            11653.566667
#       Lymphoma        12133.850000
#       Other           20487.883333
#       Prostate        11731.316667
# 2011  AllSites       127559.300000
#       Breast          16589.483333
#       Colorectal      13880.250000
#       Leukemia         5552.866667
#       Lung            11928.783333
#       Lymphoma        12526.050000
#       Other           21462.950000
#       Prostate        12123.883333
# 2012  AllSites       131526.466667
#       Breast          17060.683333
#       Colorectal      14156.450000
#       Leukemia         5739.366667
#       Lung            12206.533333
#       Lymphoma        12926.683333
#       Other           22457.916667
#       Ovary            5003.583333
#       Prostate        12532.750000
# 2013  AllSites       135538.600000
#       Breast          17531.716667
#       Colorectal      14437.133333
#       Leukemia         5931.850000
#       Lung            12484.733333
#       Lymphoma        13335.200000
#       Other           23440.616667
#       Ovary            5072.900000
#       Prostate        12957.350000
# 2014  AllSites       139690.483333
#       Brain            5086.216667
#       Breast          18010.683333
#       Colorectal      14736.050000
#       Leukemia         6131.333333
#       Lung            12773.400000
#       Other           4915.116667
#       Ovary           1155.133333
#       Pancreas        1839.383333
#       Prostate        5948.283333
#       Stomach          913.650000
#       Uterus          1279.316667
# 2019  AllSites       48958.783333
#       Bladder         1195.266667
#       Brain           1555.233333
#       Breast          7000.833333
#       Cervix           404.616667
#       Colorectal      6662.150000
#       Esophagus        761.283333
#       Head_Neck       1220.400000
#       Kidney          1861.250000
#       Leukemia         978.016667
#       Lung            6029.733333
#       Lymphoma        4014.133333
#       Melanoma         808.250000
#       Other           4990.050000
#       Ovary           1151.816667
#       Pancreas        1901.233333
#       Prostate        6173.316667
#       Stomach          935.333333
#       Uterus          1315.833333
# 2020  AllSites       50261.433333
#       Bladder         1233.266667
#       Brain           1596.166667
#       Breast          7154.583333
#       Cervix           403.250000
#       Colorectal      6828.966667
#       Esophagus        785.816667
#       Head_Neck       1244.450000
#       Kidney          1954.216667
#       Leukemia        1006.633333
#       Lung            6170.566667
#       Lymphoma        4134.333333
#       Melanoma         846.850000
#       Other           5070.033333
#       Ovary           1149.166667
#       Pancreas        1966.816667
#       Prostate        6403.883333
#       Stomach          958.566667
#       Uterus          1353.900000
# Name: Initial Year After Diagnosis Cost, dtype: float64

# %% [markdown]
# Use the pd.concat(..., axis=1) function to then re-combine them together. Make a text cell below and explain what happened to the missing rows in the output.

# %%
pd.concat([sub1, sub2], axis =1)


#mi.to_flat_index().union(other)
# Out:
#                     Total Costs  Initial Year After Diagnosis Cost
# Year Cancer Site
# 2010 AllSites     123682.166667                       39189.633333
#      Bladder                NaN                         941.766667
#      Brain                  NaN                        1246.800000
#      Breast        16121.783333                        5769.000000
#      Cervix                 NaN                         421.500000
#      Colorectal    13611.550000                        5499.100000
#      Esophagus              NaN                         571.266667
#      Head_Neck              NaN                        1024.733333
#      Kidney                 NaN                        1215.566667
#      Leukemia       5372.783333                         774.333333
#      Lung          11653.566667                        4905.900000
#      Lymphoma      12133.850000                        3134.000000
#      Melanoma               NaN                         538.666667
#      Other         20487.883333                        4292.333333
#      Ovary                  NaN                        1182.133333
#      Pancreas               NaN                        1431.866667
#      Prostate      11731.316667                        4444.700000
#      Stomach                NaN                         775.266667
#      Uterus                 NaN                        1020.633333
# 2011 AllSites     127559.300000                       40140.266667
#      Bladder                NaN                         964.183333
#      Brain                  NaN                        1276.066667
#      Breast        16589.483333                        5898.400000
#      Cervix                 NaN                         419.316667
#      Colorectal    13880.250000                        5604.733333
#      Esophagus              NaN                         590.100000
#      Head_Neck              NaN                        1045.266667
#      Kidney                 NaN                        1273.483333
#      Leukemia       5552.866667                         793.450000
#      Lung          11928.783333                        5023.000000
#      Lymphoma      12526.050000                        3218.466667
#      Melanoma               NaN                         563.200000
#      Other         21462.950000                        4378.016667
#      Ovary                  NaN                        1179.133333
#      Pancreas               NaN                        1475.616667
#      Prostate      12123.883333                        4597.516667
#      Stomach                NaN                         789.883333
#      Uterus                 NaN                        1050.350000
# 2012 AllSites     131526.466667                       41121.316667
#      Bladder                NaN                         987.900000
#      Brain                  NaN                        1306.450000
#      Breast        17060.683333                        6028.750000
#      Cervix                 NaN                         417.216667
#      Ovary          5520.000000                        1149.166667
#      Pancreas               NaN                        1966.816667
#      Prostate      16532.800000                        6403.883333
#      Stomach                NaN                         958.566667
#      Uterus                 NaN                        1353.900000

# %% [markdown]
# Something that is not clear from the reading is this: when concat several tables together
# the index of that output will automatically be a hierchichal index? in other words the output of concat will always have a
# hierchichal index? Fail to see the point in this or how it helps me get useful information from my dataset.

# %% [markdown]
# Use the pd.merge() function to re-combine the subsets together, for the following scenarios:
# use one of on=, left_on=, or right_on= parameters, assign two different values for the how= parameter. Briefly explain your results for each case with the text cell.

# %%
#inner gets rid of NAN values, outer includes NaN values.
#left join -- favors (total cost or left column) it takes every row from sub1 even if sub2 does not have a value for it, 
#and removes the Nan values for the chosen column (in this case the left or total cost ), but will ignore the rows from sub2 that are not in sub1
#the opposite is true for right join (favors right colummn).
          
#I had to include both sub 1 and 2 here as a parameter instead of saying sub1.merge(sub2, ...) here. 
#I also had to soecify the how=left, instead of just on_left=..., because it did not recognize the keyword/command.
#I could of left it as on = , without specifying the how but that just means that it would not have a preference for 
#any particular column.I wanted to see what how it treated the NaN values on sub1, so I added the how=left.
#the result: all of the rows where we had a NaN value were removed.
pd.merge(sub1, sub2, on=['Year','Cancer Site'], how='left')
# Out:
#                     Total Costs  Initial Year After Diagnosis Cost
# Year Cancer Site
# 2010 AllSites     123682.166667                       39189.633333
#      Breast        16121.783333                        5769.000000
#      Colorectal    13611.550000                        5499.100000
#      Leukemia       5372.783333                         774.333333
#      Lung          11653.566667                        4905.900000
#      Lymphoma      12133.850000                        3134.000000
#      Other         20487.883333                        4292.333333
#      Prostate      11731.316667                        4444.700000
# 2011 AllSites     127559.300000                       40140.266667
#      Breast        16589.483333                        5898.400000
#      Colorectal    13880.250000                        5604.733333
#      Leukemia       5552.866667                         793.450000
#      Lung          11928.783333                        5023.000000
#      Lymphoma      12526.050000                        3218.466667
#      Other         21462.950000                        4378.016667
#      Prostate      12123.883333                        4597.516667
# 2012 AllSites     131526.466667                       41121.316667
#      Breast        17060.683333                        6028.750000
#      Colorectal    14156.450000                        5716.250000
#      Leukemia       5739.366667                         813.366667
#      Lung          12206.533333                        5141.683333
#      Lymphoma      12926.683333                        3305.850000
#      Other         22457.916667                        4461.450000
#      Ovary          5003.583333                        1175.966667
#      Prostate      12532.750000                        4760.450000
# 2013 AllSites     135538.600000                       42123.100000
#      Breast        17531.716667                        6159.183333
#      Colorectal    14437.133333                        5831.500000
#      Leukemia       5931.850000                         833.900000
#      Lung          12484.733333                        5260.450000
#      Lymphoma      13335.200000                        3395.400000
#      Other         23440.616667                        4541.516667
#      Ovary          5072.900000                        1172.350000
#      Prostate      12957.350000                        4932.500000
# 2014 AllSites     139690.483333                       43162.400000
#      Brain          5086.216667                        1370.866667
#      Breast        18010.683333                        6292.316667
#      Colorectal    14736.050000                        5953.050000
#      Leukemia       6131.333333                         855.300000
#      Lung          12773.400000                        5381.816667
#      Lymphoma      13756.350000                        3488.450000
#      Other         24439.983333                        4618.200000
#      Ovary          5141.500000                        1168.800000
#      Prostate      13404.550000                        5116.300000
# 2015 AllSites     143885.833333                       44237.416667
#      Brain          5252.866667                        1405.166667
#      Breast        18484.750000                        6427.816667
#      Colorectal    15039.516667                        6080.283333
#      Leukemia       6334.983333                         877.550000
#      Lung          13063.516667                        5505.483333
#      Lymphoma      14184.233333                        3584.933333
#      Other         25433.666667                        4692.600000
#      Ovary          5206.416667                        1165.200000
#      Prostate      13864.366667                        5310.883333
# 2016 AllSites     148328.550000                       45362.516667
#      Brain          5426.116667                        1441.016667
#      Breast        18977.250000                        6567.083333
#      Colorectal    15373.533333                        6215.733333
#      Kidney         5228.700000                        1611.383333
#      Leukemia       6549.766667                         901.050000
#      Lung          13373.633333                        5633.483333
#      Lymphoma      14633.766667                        3686.216667
#      Other         26472.016667                        4767.850000
#      Ovary          5273.533333                        1161.866667
#      Prostate      14358.233333                        5516.150000
# 2017 AllSites     152901.100000                       46524.016667
#      Brain          5604.183333                        1477.933333
#      Breast        19478.583333                        6708.933333
#      Colorectal    15727.400000                        6357.833333
#      Kidney         5487.400000                        1690.416667
#      Leukemia       6772.216667                         925.616667
#      Lung          13693.216667                        5763.450000
#      Lymphoma      15096.066667                        3791.400000
#      Other         27515.666667                        4841.900000
#      Ovary          5338.733333                        1158.566667
#      Prostate      14873.716667                        5729.250000
# 2018 AllSites     157587.366667                       47718.416667
#      Brain          5786.583333                        1515.916667
#      Breast        19985.150000                        6853.050000
#      Colorectal    16096.516667                        6505.916667
#      Kidney         5758.466667                        1773.516667
#      Leukemia       7001.616667                         951.166667
#      Lung          14018.400000                        5894.916667
#      Lymphoma      15568.700000                        3900.300000
#      Other         28574.883333                        4915.116667
#      Ovary          5400.583333                        1155.133333
#      Prostate      15407.400000                        5948.283333
# 2019 AllSites     162462.783333                       48958.783333
#      Brain          5974.683333                        1555.233333
#      Breast        20505.950000                        7000.833333
#      Colorectal    16489.716667                        6662.150000
#      Kidney         6044.700000                        1861.250000
#      Leukemia       7240.600000                         978.016667
#      Lung          14356.716667                        6029.733333
#      Lymphoma      16058.550000                        4014.133333
#      Other         29665.533333                        4990.050000
#      Ovary          5461.883333                        1151.816667
#      Prostate      15964.983333                        6173.316667
# 2020 AllSites     167432.833333                       50261.433333
#      Brain          6168.700000                        1596.166667
#      Breast        21030.800000                        7154.583333
#      Colorectal    16894.000000                        6828.966667
#      Kidney         6343.666667                        1954.216667
#      Leukemia       7486.166667                        1006.633333
#      Lung          14701.150000                        6170.566667
#      Lymphoma      16560.033333                        4134.333333
#      Other         30763.233333                        5070.033333
#      Ovary          5520.000000                        1149.166667
#      Prostate      16532.800000                        6403.883333

# %% [markdown]
# ### 3. Pivot Table and Crosstab
#
#     a. Use the .pivot_table() method for the following scenarios:
#
#     b. replicate the same outcome as in the hierarchical indexing above by selecting appropriate row, column, and index columns.
#
#    c. repeat the same operation by adding the margins=True parameter. Briefly explain the outcome in a text cell.
#
#     d. repeat the same operation, but embed the summary method by using aggfunc=.
#
#     e. Select two columns from your original dataset and compute the output of pd.crosstab(). Briefly explain the outcome in a text cell.

# %% [markdown]
# ### 4. post a plebe friendly video.
